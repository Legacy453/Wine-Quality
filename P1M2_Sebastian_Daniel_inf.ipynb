# %% [markdown]
# # Model Inverence

# %%
import pandas as pd

# Save mode
import joblib
import json

# Bypass agar warning tidak berpengaruh
import warnings
warnings.filterwarnings('ignore')

# %%
with open('pipeline.pkl', 'rb') as file_1:
  model = joblib.load(file_1)

# %%
data = pd.DataFrame({
    'fixed acidity': [6.8, 6.2, 5.9, 5.9, 6.0],
    'volatile acidity': [0.620, 0.600, 0.550, 0.645, 0.310],
    'citric acid': [0.08, 0.08, 0.10, 0.12, 0.47],
    'residual sugar': [1.9, 2.0, 2.2, 2.0, 3.6],
    'chlorides': [0.068, 0.090, 0.062, 0.075, 0.067],
    'free sulfur dioxide': [28.0, 32.0, 39.0, 32.0, 18.0],
    'total sulfur dioxide': [38.0, 44.0, 51.0, 44.0, 42.0],
    'density': [0.99651, 0.99490, 0.99512, 0.99547, 0.99549],
    'pH': [3.42, 3.45, 3.52, 3.57, 3.39],
    'sulphates': [0.82, 0.58, 0.76, 0.71, 0.66],
    'alcohol': [9.5, 10.5, 11.2, 10.2, 11.0],
})

# %%
data
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.8             0.620         0.08             1.9      0.068
# 1            6.2             0.600         0.08             2.0      0.090
# 2            5.9             0.550         0.10             2.2      0.062
# 3            5.9             0.645         0.12             2.0      0.075
# 4            6.0             0.310         0.47             3.6      0.067
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 28.0                  38.0  0.99651  3.42       0.82
# 1                 32.0                  44.0  0.99490  3.45       0.58
# 2                 39.0                  51.0  0.99512  3.52       0.76
# 3                 32.0                  44.0  0.99547  3.57       0.71
# 4                 18.0                  42.0  0.99549  3.39       0.66
#
#    alcohol
# 0      9.5
# 1     10.5
# 2     11.2
# 3     10.2
# 4     11.0

# %%
data['quality']= model.predict(data)

# %%
data
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.8             0.620         0.08             1.9      0.068
# 1            6.2             0.600         0.08             2.0      0.090
# 2            5.9             0.550         0.10             2.2      0.062
# 3            5.9             0.645         0.12             2.0      0.075
# 4            6.0             0.310         0.47             3.6      0.067
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 28.0                  38.0  0.99651  3.42       0.82
# 1                 32.0                  44.0  0.99490  3.45       0.58
# 2                 39.0                  51.0  0.99512  3.52       0.76
# 3                 32.0                  44.0  0.99547  3.57       0.71
# 4                 18.0                  42.0  0.99549  3.39       0.66
#
#    alcohol  quality
# 0      9.5        1
# 1     10.5        0
# 2     11.2        1
# ...
